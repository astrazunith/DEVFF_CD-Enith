# %% [markdown]
# # **HANDS - ON: INTRODUCCIÓN A LAS FUNCIONES**

# %% [markdown]
# Una vez visto la presentación ***Introducción a las funciones***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/19WfNFwr8eu0YK3MGQh4RBczbKfbcqvgI?usp=sharing).

# %% [markdown]
# ## **FUNCIÓN INTEGRADA**

# %% [markdown]
# Una **función integrada** es un bloque de código reutilizable
#  predefinida en python que se utiliza para **realizar una tarea específica y están disponibles para su uso en cualquier momento** sin la necesidad de importar ningún módulo.

# %% [markdown]
# Una función integrada tiene la siguiente estructura:
#
# ```
# nombre_funcion(parametro1, parametro2, ...)
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Imprime una cadena de caracteres:

# %%
# difinir función
print('Hola,mundo!!')
# Out:
# Hola,mundo!!

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Devuelve la longitud de una lista:

# %%
# difinir función
len([1, 2, 3, 4, 5])
# Out:
# 5

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Devuelve una lista ordenada de elementos:

# %%
# difinir función
sorted([2, 4, 1, 5, 3])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Redondea un número según un número determinado de decimales:

# %%
# difinir función
round(3.14159265, 4)
# Out:
# 3.1416

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
# Devuelve el valor mínimo en una lista:

# %%
# difinir función
min([3, 6, 7, 2, 10, 2])
# Out:
# 2

# %% [markdown]
# ## **FUNCIÓN DEFINIDA POR EL USUARIO**

# %% [markdown]
# Una **función definida por el usuario** es creada de manera personalizada para realizar tareas específicas y reutilizables en todo el programa. Este tipo de función se crea utilizando la palabra clave ` def` seguida del nombre de la función y los parámetros, si los hay.

# %% [markdown]
# Una función definida por el usuario tiene la siguiente estructura:
#
# ```
# def nombre_funcion(parametro1, parametro2, ...):
#     # Código que realiza una tarea específica
#
#     # Devolver un valor (opcional)
#     return valor
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Función que calcula el cuadrado de un número:

# %%
# difinir función
numero = int(input('Ingresa un número: '))

def calcular_cuadrado(numero):
  """
  Función -> calcular_cuadro: Calcula el cuadrado de un número.
  Param   -> numero: Valor numerico (No cadena de texto).
  Return  -> El número ingresado elevado al cuadrado.
  """
  # cuadrado = numero ** 2
  return numero ** 2

print(calcular_cuadrado(numero))
# Out:
# Ingresa un número: 10
# 100

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Función para verificar si un número es par o impar:

# %%
# difinir función
numero = int(input('Ingresa un número: '))

def detectar_par(numero):
  """
  Función -> detectar_par: Detecta si el número ingresado es par o impar
  Param   -> numero: Valor numerico (No cadena de texto).
  """
  if numero % 2 == 0:
    print('Par')
  else:
    print('Impar')

detectar_par(numero)
# Out:
# Ingresa un número: 67
# Impar

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Función para calcular el factorial de un número:

# %%
# difinir función
numero = int(input('Ingresa un número: '))

def calcular_factorial(numero):
  """
  Función -> calcular_factorial: Calcula el factorial de un número.
  Param   -> numero: Valor numerico (No cadena de texto).
  Return  -> Regresa el valor anterior al momento de volver a invocar el número.
             Hasta que llege a cero, y comienza retornar sus valores de pendiendo
             de la profunddad.
  """
  if numero == 0:
    return 1
  else:
    return numero * calcular_factorial(numero - 1)

calcular_factorial(numero)
# Out:
# Ingresa un número: 5
# 120

# %%
"""
Primer vuelta
numero = 3
retornar 3 * 2

Segunda vuelta
numero = 2
retornar 2 * 1

Tercer vuelta:
numero = 1
retornar 1 * 1

Cuarta vuelta:
numero = 0
retornar 1
"""
# Out:
# '\nPrimer vuelta\nnumero = 3\nretornar 3 * 2\n\nSegunda vuelta\nnumero = 2\nretornar 2 * 1\n\nTercer vuelta:\nnumero = 1\nretornar 1 * 1\n\nCuarta vuelta:\nnumero = 0\nretornar 1\n'

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Función para unir dos listas en una sola lista:

# %%
# definir listas
lista_uno = [1, 2]
lista_dos = [3, 4, 5]

# %%
# difinir función
def unir_listas(lista_uno, lista_dos):
  """
  Función -> unir_listas: Une dos listas, volviendolo solamente uno.
  Param   -> lista_uno: Lista que contenga o no valores dentro.
          -> lista_dos: Lista que contenga o no valores dentro.
  Return  -> Regresa una sola lista con el contenido de las listas ingresadas.
  """
  # lista_unida = lista_uno + lista_dos
  return lista_uno + lista_dos

unir_listas(lista_uno, lista_dos)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
#  Función para buscar elementos dentro de un diccionario

# %%
# definir diccionario

capitales = {'México': 'Toluca', 'Nuevo León': 'Monterrey', 'Jalisco': 'Guadalajara'}

# %%
# difinir función
estado = input('Ingrese un estado: ')

def buscar_capital(capitales, estado):
  """
  Función -> buscar_capital: Busca la capital asociada a los estados disponibles.
  Param   -> capitales: Disccionario que contiene tanto los estados como sus capitales disponibles.
          -> estado: El estado que se usará para buscar la capital.
  Return  -> Regresa la capital asociada al estado ingresado.
  """
  return capitales.get(estado)

buscar_capital(capitales, estado)
# Out:
# Ingrese un estado: Jalisco
# 'Guadalajara'

# %% [markdown]
# ## **CHALLENGE: AGENDA CON MENÚ CRUD**

# %% [markdown]
# Una vez visto el ***Hands - On: Introducción a las funciones***, se presentan la siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se utilizará el challenge del menú** para **separar por funciones los procesos del CRUD** donde **cada función será invocado dentro del ciclo donde se muestra el menú**, todo lo anterior haciendo uso de **Python**.
#
# Cada función deberá ejecutar cada operación del CRUD:
#
# *   **Ver agenda**
# *   **Crear contacto**
# *   **Consultar contacto**
# *   **Actualizar contacto**
# *   **Eliminar contacto**
# *   **Salir menú**

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Crea la Agenda:** Construye la agenda con los registros utilizados en las prácticas anteriores.

# %%
# Definir agenda
contacto1 = {"Nombre" : "Rosa", "Teléfono" : "1221330965", "Correo" : "rosa@proton.me"}
contacto2 = {"Nombre" : "Violeta", "Teléfono" : "5373573011", "Correo" : "violeta@tu-braunschweig.de"}
contacto3 = {"Nombre" : "Blanca", "Teléfono" : "5678893113", "Correo" : "blanca@unam.ciencias.mx"}
Agenda = [contacto1, contacto2, contacto3]

# %% [markdown]
# **2. Define una función que muestre las opciones del menú CRUD:**
#
#    * Crea una función que muestre el menú CRUD para la agenda con las opciones:
#
#    ```
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#    ```

# %%
# Crear función menú opciones

def imprimir_agenda():
  '''
  Función -> imprimir_agenda: Tiene alojada una cadena de texto con el menú de opciones para una agenda
  Return  -> Regresa una cadena de texto con el menu de opciones, para que se visualicen se requiere que se llame print y luego la función.
  '''
  menu_CRUD = '''
********** MENU **********
1. Ver agenda
2. Crear contacto
3. Consultar contacto
4. Actualizar contacto
5. Eliminar contacto
6. Salir menú
'''
  return menu_CRUD

# %% [markdown]
# **3. Define una función que imprima todos los contactos de la agenda:**
#
#    * Crea una función que realice un ciclo for que recorra y muestre cada contacto de la agenda.
#    * Dentro del ciclo, muestra el número de contacto por cada iteración.

# %%
# Crear función mostrar agenda

def mostrar_contactos(agenda:list):
  '''
  Función -> mostrar_contactos: Imprime los contactos (diccionario) de una Agenda (lista) en forma de cadena de texto.
  Param   -> agenda: Lista que contiene tres diccionarios, cada uno es un contacto con Nombre, teléfono y correo
  Return  -> No regresa nada, por lo que es None.
  '''
  numero_contacto = 0
  contactos = ""
  for contacto in agenda:
    numero_contacto += 1
    print(f'{contacto} son los datos del contacto {numero_contacto}')

# %% [markdown]
# **4. Define una función para crear un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre, teléfono y correo para un contacto.
#    * Guarda estos datos en un diccionario llamado contacto.
#    * Imprime el mensaje "Contacto creado con éxito".

# %%
# Crear función crear contacto
def crear_contacto(agenda):
  '''
  Función -> crear_contacto: Agrega un  contacto nuevo (diccionario) al final de la lista de contactos
  Param   -> agenda: Lista que contiene diccionarios, cada uno es un contacto con Nombre, Teléfono y Correo
  '''
  contacto=Agenda.append({'Nombre': input('Ingresa el nombre del contacto: '),
                          'Teléfono': input('Ingresa su teléfono: '), 'Correo': input('Ingresa su correo: ')})
  print("¡Contacto creado con éxito!")

# %% [markdown]
# **5. Define una función para consultar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a consultar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces imprime el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función consultar contacto
def consultar_contacto(agenda):
  '''
  Función -> consultar_contacto: Se le pide al usuario ingresar un nombre a consultar, el cuál se guarda en una variable,
  mediante un ciclo for se consulta cada contacto (diccionario) de una agenda (lista), y con un condicional if se verifica si el nombre buscado
  está "asignado" a la clave nombre, si está se dan los datos del contacto, sino, se devuelve un mensaje de contacto no encontrado
  Param   -> agenda: lista que contiene diccionarios, cada uno es un contacto con Nombre, Teléfono y Correo
  Return -> None
  '''
  nombre_buscado = input("Ingresa el nombre del contacto a consultar: ")
  for contacto in Agenda:
    if nombre_buscado == contacto['Nombre']:
      print(f' Datos: {contacto}')
      break
  else:
      print("Contacto no encontrado")

# %% [markdown]
# **6. Define una función para actualizar un contacto de la agenda:**
#
#  (Dada la complejidad y extensión de este punto se separará por partes).
#
#    * Crea una función que visualice un menú que contenga las siguientes opciones:
#
#    ```
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#    ```

# %%
# Crear función menú para actualizar contacto
def menu_actualizar_contacto():
  '''
  Función -> menu_actualizar_contacto: Guarda en una variable una cadena de texto que contiene el menú de opciones
  Return  -> Regresa la variable donde se guardó la cadena de texto que contiene el menú de opciones
  '''
  menu_actualizar_contacto = '''
  ********** Menu actualizar contacto **********
1. Actualizar nombre
2. Actualizar teléfono
3. Actualizar correo
4. Salir del menu
  '''
  return menu_actualizar_contacto

# %% [markdown]
#    * Crea una función que realice un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces retorna el contacto encontrado.
#    * De lo contrario, entonces retorna `None`.

# %%
# Crear función buscador contacto para actualizar contacto
def buscar_contacto(agenda):
  '''
  Función -> buscar_contacto: Imprime los contactos (diccionario) de una Agenda (lista) en forma de cadena de texto.
  Param   -> agenda: lista que contiene diccionarios, cada uno es un contacto con Nombre, Teléfono y Correo
  Return  -> Regresa los datos del contacto sobre el que actualmente se está iterando
  '''
  nombre_buscado = input("Ingresa el nombre del contacto a consultar: ")
  for contacto in agenda:
    if nombre_buscado == contacto['Nombre']:
      return contacto

# %% [markdown]
#    * Crea una función para cada opción a escojer, modificando ya sea el nombre, el teléfono o el correo del contacto encontrado por nuevos registros.
#    * Por cada registro nuevo ingresado, imprime el contacto para visualizar los cambios.

# %%
# Crear función actualizar nombre para actualizar contacto
def actualizar_nombre(agenda):
  '''
  Función -> actualizar_nombre: Esta función llama a la función buscar_contacto para verificar que el nombre que se quiera actualizar exista dentro de la agenda,
  si es así, se entra en la condición if que pide el nuevo nombrey se guarda en el diccionario para la clave Nombre, de lo contrario se imprime el mensaje que
  no se encontró el contacto
  Param   -> agenda: lista que contiene diccionarios, cada uno es un contacto con Nombre, Teléfono y Correo
  Return  -> No regresa nada, por lo que es None.
  '''
  contacto = buscar_contacto(agenda)
  if contacto != None:
    clave_nombre = input('Ingresa un nuevo nombre: ')
    contacto['Nombre'] = clave_nombre
    print("Nombre actualizado:", contacto)
  else:
    print("No se encontró contacto con ese nombre")

# %%
# Crear función actualizar telefono para actualizar contacto
def actualizar_telefono(agenda):
  '''
  Función -> actualizar_teléfono: Esta función llama a la función buscar_contacto para verificar que el nombre que se quiera actualizar exista dentro de la agenda,
  si es así, se entra en la condición if que pide el nuevo teléfono y se guarda en el diccionario para la clave Teléfono, de lo contrario se imprime el mensaje que
  no se encontró el contacto
  Param   -> agenda: lista que contiene diccionarios, cada uno es un contacto con Nombre, Teléfono y Correo
  Return  -> No regresa nada, por lo que es None.
  '''
  contacto = buscar_contacto(agenda)
  if contacto != None:
    clave_telefono = input('Ingresa un nuevo teléfono: ')
    contacto['Teléfono'] = clave_telefono
    print("Teléfono actualizado:", contacto)
  else:
    print("No se encontró contacto con ese nombre")

# %%
# Crear función actualizar correo para actualizar contacto
def actualizar_correo(agenda):
  '''
  Función -> actualizar_correo: Esta función llama a la función buscar_contacto para verificar que el nombre que se quiera actualizar exista dentro de la agenda,
  si es así, se entra en la condición if que pide el nuevo correo y se guarda en el diccionario para la clave Correo, de lo contrario se imprime el mensaje que
  no se encontró el contacto
  Param   -> agenda: lista que contiene diccionarios, cada uno es un contacto con Nombre, Teléfono y Correo
  Return  -> No regresa nada, por lo que es None.
  '''
  contacto = buscar_contacto(agenda)
  if contacto != None:
    clave_correo = input('Ingresa un nuevo correo: ')
    contacto['Correo'] = clave_correo
    print("Correo actualizado:", contacto)
  else:
    print("No se encontró contacto con ese nombre")

# %% [markdown]
#    * Crea una función que integre las funciones creadas anteriormente a través de un ciclo while para un menú de actualizar un contacto.
#    * Pide al usuario que ingrese el nombre del contacto a actualizar.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función actualizar contacto
def actualizar_contacto(agenda):
  '''
  Función -> actualizar_contacto: Esta función imprime la función menu_actualizar_contacto(), luego se le pide al usuario que ingrese una opción según
  lo que se vió en pantalla, con if y elif se compara que número eligió el usuario y se ejecuta cierta función según la opción, si la opción no coincide con algún if
  o elif, se imprime el mensaje: Opción no válida
  Param   -> agenda: lista que contiene diccionarios, cada uno es un contacto con Nombre, Teléfono y Correo
  Return  -> No regresa nada, por lo que es None.
  '''
  while True:
    print(menu_actualizar_contacto())
    opcion_menu_actu_contacto = int(input("Ingrese una opción: "))

    if opcion_menu_actu_contacto == 1:
      actualizar_nombre(agenda)

    elif opcion_menu_actu_contacto == 2:
      actualizar_telefono(agenda)

    elif opcion_menu_actu_contacto == 3:
      actualizar_correo(agenda)

    elif opcion_menu_actu_contacto == 4:
      print("Saliendo del menú...")
      break

    else:
      print("Opción no válida")

# %% [markdown]
# **7. Define una función para eliminar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a eliminar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces elimina el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función eliminar contacto
def eliminar_contacto(agenda):
  '''
  Función -> eliminar_contacto: Esta función pide el nombre a buscar y lo guarda en una variable, también se define el número de contacto como igual a cero,
  se itera sobre cada diccionario en la lista (Agenda) y si el nombre buscado coincide con la clave Nombre del diccionario actual, se elimina todo el diccionario
  y se imprime el mensaje de contacto eliminado. La variable num_contacto se va aumentando por cada iteración para utilizar la función pop. Si no se encuentra el nombre
  se imprime el mensaje: Contacto no encontrado
  Param   -> agenda: lista que contiene diccionarios, cada uno es un contacto con Nombre, Teléfono y Correo
  Return  -> No regresa nada, por lo que es None.
  '''
  nombre_buscado_eliminar = input("Ingresa el nombre del contacto a eliminar: ")
  num_contacto = 0
  for contacto in Agenda:
    if nombre_buscado_eliminar == contacto['Nombre']:
      Agenda.pop(num_contacto)
      print("Contacto eliminado")
      break
    num_contacto += 1
  else:
    print("Contacto no encontrado")

# %% [markdown]
# **8. Junta todas las funciones del menú CRUD dentro de una función:**
#
#    * Crea una función crear un menú a través de un ciclo while.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función menú agenda
def menu_crud_agenda(opcion):
  '''
  Función -> menu_crud_agenda: Esta función imprime la función imprimir_Agenda(), luego se le pide al usuario que ingrese una opción según
  lo que se vió en pantalla, con if y elif se compara que número eligió el usuario y se ejecuta cierta función según la opción, si la opción no coincide con algún if
  o elif, se imprime el mensaje: Opción no encontrada
  Param   -> opcion: Variable entera ingresada por el usuario
  Return  -> No regresa nada, por lo que es None.
  '''
  while True:
    print(imprimir_agenda())
    opcion = int(input("Seleccione una opción: "))

    if opcion == 1:
      mostrar_contactos(Agenda)

    elif opcion == 2:
      crear_contacto(Agenda)

    elif opcion == 3:
      consultar_contacto(Agenda)

    elif opcion == 4:
      actualizar_contacto(Agenda)

    elif opcion == 5:
      eliminar_contacto(Agenda)

    elif opcion == 6:
      print("Saliendo del menú...")
      break

    else:
      print("Opción no encontrada")

menu_crud_agenda(opcion)
# Out:
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 1
# {'Nombre': 'Rosa', 'Teléfono': '1221330965', 'Correo': 'rosa@proton.me'} son los datos del contacto 1
# {'Nombre': 'Violeta', 'Teléfono': '5373573011', 'Correo': 'violeta@tu-braunschweig.de'} son los datos del contacto 2
# {'Nombre': 'Blanca', 'Teléfono': '5678893113', 'Correo': 'blanca@unam.ciencias.mx'} son los datos del contacto 3
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 2
# Ingresa el nombre del contacto: Azul
# Ingresa su teléfono: 5687439013
# Ingresa su correo: azul_estrella@gmail.com
# ¡Contacto creado con éxito!
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 1
# {'Nombre': 'Rosa', 'Teléfono': '1221330965', 'Correo': 'rosa@proton.me'} son los datos del contacto 1
# {'Nombre': 'Violeta', 'Teléfono': '5373573011', 'Correo': 'violeta@tu-braunschweig.de'} son los datos del contacto 2
# {'Nombre': 'Blanca', 'Teléfono': '5678893113', 'Correo': 'blanca@unam.ciencias.mx'} son los datos del contacto 3
# {'Nombre': 'Azul', 'Teléfono': '5687439013', 'Correo': 'azul_estrella@gmail.com'} son los datos del contacto 4
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 2
# Ingresa el nombre del contacto: Azu
# Ingresa su teléfono: 7856431210
# Ingresa su correo: azucena@hotmail.com
# ¡Contacto creado con éxito!
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 1
# {'Nombre': 'Rosa', 'Teléfono': '1221330965', 'Correo': 'rosa@proton.me'} son los datos del contacto 1
# {'Nombre': 'Violeta', 'Teléfono': '5373573011', 'Correo': 'violeta@tu-braunschweig.de'} son los datos del contacto 2
# {'Nombre': 'Blanca', 'Teléfono': '5678893113', 'Correo': 'blanca@unam.ciencias.mx'} son los datos del contacto 3
# {'Nombre': 'Azul', 'Teléfono': '5687439013', 'Correo': 'azul_estrella@gmail.com'} son los datos del contacto 4
# {'Nombre': 'Azu', 'Teléfono': '7856431210', 'Correo': 'azucena@hotmail.com'} son los datos del contacto 5
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 3
# Ingresa el nombre del contacto a consultar: Azucena
# Contacto no encontrado
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 4
#
#   ********** Menu actualizar contacto **********
# 1. Actualizar nombre
# 2. Actualizar teléfono
# 3. Actualizar correo
# 4. Salir del menu
#
# Ingrese una opción: 1
# Ingresa el nombre del contacto a consultar: Azu
# Ingresa un nuevo nombre: Azucena
# Nombre actualizado: {'Nombre': 'Azucena', 'Teléfono': '7856431210', 'Correo': 'azucena@hotmail.com'}
#
#   ********** Menu actualizar contacto **********
# 1. Actualizar nombre
# 2. Actualizar teléfono
# 3. Actualizar correo
# 4. Salir del menu
#
# Ingrese una opción: 2
# Ingresa el nombre del contacto a consultar: Azucena
# Ingresa un nuevo teléfono: 7645321245
# Teléfono actualizado: {'Nombre': 'Azucena', 'Teléfono': '7645321245', 'Correo': 'azucena@hotmail.com'}
#
#   ********** Menu actualizar contacto **********
# 1. Actualizar nombre
# 2. Actualizar teléfono
# 3. Actualizar correo
# 4. Salir del menu
#
# Ingrese una opción: 3
# Ingresa el nombre del contacto a consultar: Azucena
# Ingresa un nuevo correo: azucena_r@hotmail.com
# Correo actualizado: {'Nombre': 'Azucena', 'Teléfono': '7645321245', 'Correo': 'azucena_r@hotmail.com'}
#
#   ********** Menu actualizar contacto **********
# 1. Actualizar nombre
# 2. Actualizar teléfono
# 3. Actualizar correo
# 4. Salir del menu
#
# Ingrese una opción: 4
# Saliendo del menú...
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 5
# Ingresa el nombre del contacto a eliminar: Azu
# Contacto no encontrado
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 5
# Ingresa el nombre del contacto a eliminar: Azul
# Contacto eliminado
#
# ********** MENU **********
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
#
# Seleccione una opción: 6
# Saliendo del menú...
