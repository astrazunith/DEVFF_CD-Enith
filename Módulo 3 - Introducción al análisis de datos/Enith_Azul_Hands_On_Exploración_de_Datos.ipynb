# %% [markdown]
# # **HANDS - ON: EXPLORACIÓN DE DATOS**

# %% [markdown]
# Una vez visto la presentación ***Exploración de datos***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.
#
# Para este notebook, se hará uso del siguiente dataset: [enlace](https://drive.google.com/file/d/1hX8uxJp5h03eYrgAnyznp8yeeG2syiD_/view?usp=drive_link)
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/1eXIB1nd8aaBZWDYBXlIlfCOVkAe-ETrI?usp=drive_link).

# %% [markdown]
# ## **ANÁLISIS EXPLORATPRIO**

# %% [markdown]
# El **Análisis Exploratorio de Datos (EDA)** es la etapa donde **se descubren patrones, se detectan anomalías y se comprueban hipótesis mediante estadísticas y visualizaciones**. Es el proceso fundamental para entender la salud de la información antes de cualquier toma de decisiones.
#
# A través de herramientas descriptivas y gráficos de dispersión, esta fase permite limpiar inconsistencias y validar la calidad de la muestra. Su ejecución garantiza que las conclusiones posteriores se apoyen en evidencia real, minimizando sesgos y optimizando la precisión de los modelos predictivos.

# %%
# Importar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Importar datos
ruta_colab = '/content/youtube_clean.csv'
df_yt = pd.read_csv(ruta_colab)

df_yt
# Out:
#      video_id      título   categoría   views    likes  dislikes  comentarios  \
# 0           1      título      música  129257    11299        21         8790
# 1           2      título   películas  247904    15579       211         4775
# 2           3  sin título     comedia    3073    14780      1095         9847
# 3           4      título      gaming  268858     2691      4420         7614
# 4           5      título      gaming  162893    16521      2294         6508
# ..        ...         ...         ...     ...      ...       ...          ...
# 303       106      título   películas  150272    11299      4605         6716
# 304       131      título  tecnología   25407  9999999      2437         4498
# 305         6      título   películas   42160    10721      3547         9033
# 306        97      título    deportes   13530    14437      2631         2629
# 307       210      título   películas   71075    19940       223         2832
#
#      duración_min fecha_publicación
# 0             127        2024-07-02
# 1              63        2022-02-13
# 2              55        2016-07-06
# 3              78        2017-12-03
# 4             143        2023-11-24
# ..            ...               ...
# 303           213        2021-09-04
# 304           137        2025-07-18
# 305            58        2025-08-27
# 306           158        2018-03-12
# 307            51        2016-11-08
#
# [308 rows x 9 columns]

# %%
# Ver resumen estadístico de las columnas numéricas
columnas_numericas = ['views', 'likes', 'comentarios', 'dislikes', 'duración_min']

df_yt[columnas_numericas].describe()
# Out:
#                views         likes  comentarios       dislikes  duración_min
# count     308.000000  3.080000e+02   308.000000     308.000000    308.000000
# mean   144805.269481  6.265995e+05  5058.188312   12193.288961    139.853896
# std     86246.543475  2.407311e+06  2940.396104   52900.153300    139.066834
# min      1691.000000  9.700000e+01    12.000000      21.000000      1.000000
# 25%     74129.500000  5.774250e+03  2667.500000    1523.750000     58.000000
# 50%    129257.000000  1.129900e+04  4931.500000    2590.000000    123.500000
# 75%    224050.750000  1.575300e+04  7740.750000    3777.500000    181.500000
# max    299408.000000  9.999999e+06  9987.000000  300408.000000    800.000000

# %% [markdown]
# ### **VALORES ATÍPICOS Y TRATAMIENTO**

# %% [markdown]
# **Los valores atípicos son observaciones que se alejan significativamente del resto de los datos**. Pueden ser causados por errores en la entrada de datos o por fenómenos naturales del dataset.

# %%
# Observar distribución de los datos
plt.figure(figsize=(15,9))

for i, col in enumerate(columnas_numericas, 1):
  plt.subplot(2, 3, i)
  sns.histplot(df_yt[col], bins=30, kde=True, color='teal')
  plt.title(f'Distribución de {col}')
  plt.xlabel(col)
  plt.ylabel('Frecuencia')
  plt.grid(axis='y', alpha = 0.75)

plt.tight_layout()
plt.show()

# %%
# Observar comportamiento cuartil de los datos
plt.figure(figsize=(15,9))

for i, col in enumerate(columnas_numericas, 1):
  plt.subplot(2, 3, i)
  sns.boxplot(x = df_yt[col], color = 'pink')
  plt.title(f'Diagrama de caja y bigotes: {col}')
  plt.xlabel(col)
  plt.grid(axis='x', alpha = 0.75)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **RANGO INTERCUARTILICO**

# %% [markdown]
# El **Rango Intercuartílico (IQR)** es una medida fundamental de dispersión estadística, utilizada principalmente para detectar y manejar **valores atípicos (outliers)** en un conjunto de datos. Se calcula como la diferencia entre el tercer cuartil (Q3) y el primer cuartil (Q1):
#
# $$IQR = Q3 - Q1$$
#
# Para identificar outliers, se definen límites:
#
# *   **Límite Inferior (LI):** $LI = Q1 - 1.5 \times IQR$
#
# *   **Límite Superior (LS):** $LS = Q3 + 1.5 \times IQR$

# %%
# Ver cantidad de registros iniciales
print(f'Cantidad de datos iniciles: {len(df_yt)}')
# Out:
# Cantidad de datos iniciles: 308

# %%
# Calculo del IQR
df_copy=df_yt.copy()
for col in columnas_numericas:
  Q1 = df_copy[col].quantile(0.25)
  Q3 = df_copy[col].quantile(0.75)
  IQR = Q3 - Q1

  lim_inf_iqr=Q1-1.5*IQR
  lim_sup_iqr=Q3+1.5*IQR

  cant_inicial = len(df_copy)
  df_copy = df_copy[(df_copy[col] >= lim_inf_iqr) & (df_copy[col] <= lim_sup_iqr)]
  cant_final = len(df_copy)

  print(f'Cantidad de datos con outliers eliminados en {col}: {cant_inicial - cant_final}')
# Out:
# Cantidad de datos con outliers eliminados en views: 0
# Cantidad de datos con outliers eliminados en likes: 19
# Cantidad de datos con outliers eliminados en comentarios: 0
# Cantidad de datos con outliers eliminados en dislikes: 10
# Cantidad de datos con outliers eliminados en duración_min: 10

# %%
# Ver cantidad de registros finales y proporción con la cantidad inicial
prop_cant_datos = round((len(df_copy) / len(df_yt)) * 100, 2)

print(f'Cantidad de datos finales: {len(df_copy)}')
print(f'Proporción de datos útiles: {prop_cant_datos}%')
# Out:
# Cantidad de datos finales: 269
# Proporción de datos útiles: 87.34%

# %%
# Observar comportamiento cuartil final de los datos
plt.figure(figsize=(15,9))

for i, col in enumerate(columnas_numericas, 1):
  plt.subplot(2, 3, i)
  sns.boxplot(x = df_copy[col], color = 'pink')
  plt.title(f'Diagrama de caja y bigotes: {col}')
  plt.xlabel(col)
  plt.grid(axis='x', alpha = 0.75)

plt.tight_layout()
plt.show()

# %%
# Observar distribución de los datos sin outliers
plt.figure(figsize=(15,9))

for i, col in enumerate(columnas_numericas, 1):
  plt.subplot(2, 3, i)
  sns.histplot(df_copy[col], bins=30, kde=True, color='teal')
  plt.title(f'Distribución de {col}')
  plt.xlabel(col)
  plt.ylabel('Frecuencia')
  plt.grid(axis='y', alpha = 0.75)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **CORRELACIÓN NUMÉRICA**

# %% [markdown]
# La **correlación numérica** es una medida estadística que **indica la fuerza y dirección de la relación lineal entre dos o más variables numéricas**. Puede utilizar el coeficiente de correlación de Pearson (el más común) para determinar la dirección (positiva, negativa, nula).

# %%
# Realizar matriz de correlación
corr_matrix = df_copy[columnas_numericas].corr()

plt.figure(figsize = (10, 8))
sns.heatmap(corr_matrix, annot = True, cmap = 'coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title('Matriz de Correlación')
plt.show()

# %%
# Realizar correlaciones divididas

metricas = ['views', 'likes', 'dislikes', 'comentarios', 'duración_min']

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(36, 12))
axes = axes.flatten() # Aplanamos para iterar fácilmente

# Pares de comparación por
comparaciones = [
    ('views', 'likes'), ('views', 'comentarios'), ('views', 'dislikes'),
    ('views', 'duración_min'), ('likes', 'comentarios'), ('likes', 'dislikes'),
    ('likes', 'duración_min'), ('dislikes', 'comentarios'),
    ('dislikes', 'duración_min'), ('comentarios', 'duración_min')
]

for i, (col_x, col_y) in enumerate(comparaciones):
    sns.regplot(ax=axes[i], data=df_copy, x=col_x, y=col_y,
                scatter_kws={'alpha':0.3, 'color':'darkorchid'},
                line_kws={'color':'blue'})
    axes[i].set_title(f'{col_x.title()} vs {col_y.title()}')
    axes[i].grid(True, alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **COMPARACIÓN POR CATEGÓRICA**

# %% [markdown]
# La **comparación por categórica** implica analizar cómo las variables numéricas se comportan o distribuyen a través de diferentes grupos o categorías. Este tipo de análisis es fundamental para entender: **distribuciones, tendencias y relaciones**
#
# Para visualizar estas comparaciones, son muy útiles los **gráficos de barras**, donde se pueden mostrar las cantidades o promedios de una variable numérica para cada categoría, o los **diagramas de caja (boxplots)**, que revelan la distribución completa de los datos dentro de cada grupo, incluyendo la mediana, cuartiles y posibles valores atípicos.

# %%
# Realizar gráficos de barras divididas
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
orden = df_copy['categoría'].value_counts().index # Ordenar de mayor a menor
sns.countplot(data=df_copy, y='categoría', order=orden, palette='viridis', hue='categoría', legend=False)
plt.title('Distribución de Videos por Categoría', fontsize=14)
plt.xlabel('Cantidad de Videos')
plt.ylabel('Categoría')
plt.grid(axis='x', linestyle='--', alpha=0.6)

plt.subplot(1, 2, 2)
sns.barplot(data=df_copy, x='comentarios', y='categoría',
            estimator='mean', palette='viridis', errorbar=None, hue='categoría', legend=False)
plt.title('Promedio de Comentarios por Categoría')
plt.xlabel('Comentarios Promedio')

plt.tight_layout()
plt.show()

# %%
# Realizar gráfico de barras y caja divididos
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.barplot(data=df_copy, x='views', y='categoría',
            estimator='mean', palette='magma', errorbar=None, hue='categoría', legend=False)
plt.title('Promedio de Vistas por Categoría')
plt.xlabel('Vistas Promedio')

plt.subplot(1, 2, 2)
sns.boxplot(data=df_copy, x='categoría', y='views', palette='magma', hue='categoría', legend=False)
plt.title('Distribución de Vistas por Categoría')
plt.xlabel('Categoría')
plt.ylabel('Vistas')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.75)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **NARRATIVA VISUAL**

# %% [markdown]
# La **visualización narrativa** es la fusión estratégica entre la **claridad de los gráficos** y el **impacto del storytelling para comunicar mensajes** memorables. No se limita a exponer cifras, sino que construye un relato donde los datos actúan como evidencia para guiar a la audiencia hacia una conclusión clara.
#
# Al conectar puntos de datos con una estructura narrativa, se logra captar la atención emocional y lógica del espectador. Esta técnica transforma estadísticas frías en una historia coherente, facilitando la comprensión de tendencias complejas y asegurando que los hallazgos clave impulsen una toma de decisiones informada.

# %% [markdown]
# ### **PROPORCIÓN DE DATOS A MOSTRAR**

# %%
# Definir variables para la agrupación
categoria = lambda x: 'Sin Categoría' if x == 'sin categoría' else 'Con Categoría'
df_yt['agruepacion_cat'] = df_yt['categoría'].apply(categoria)
pie_data = df_yt['agruepacion_cat'].value_counts()

# %%
# Realizar gráfico de dona

colors_pie = ['#001A70', '#E6E8F0'] # Azul = "Con Categoría", Gris = "Sin Categoría"
explode_val = 0.2 # Valor de separación

# Gráfico de pastel

plt.figure(figsize=(6, 6))
wedges, texts, autotexts = plt.pie(pie_data,
                                   labels=pie_data.index,
                                   autopct='%1.1f%%',
                                   startangle=90,
                                   colors=colors_pie,
                                   textprops={'fontsize': 12, 'fontweight': 'bold'},
                                   pctdistance=0.85, # Mueve el porcentaje hacia afuera
                                   explode=(explode_val, 0)) # Resalta ligeramente la porción principal

# Círculo blanco central (estilo moderno)

theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center_angle = np.deg2rad((theta1 + theta2) / 2) # Obtención el ángulo medio

cx = explode_val * np.cos(center_angle) # Se Calcula nueva posición con trigonometría
cy = explode_val * np.sin(center_angle)

centre_circle = plt.Circle((cx, cy), 0.70, fc='white') # Se dibuja el circulo
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Proporción Categórica de Videos', fontsize=16, fontweight='bold', pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **DISTRIBUCIÓN DE VÍDEOS POR CATEGORÍA**

# %%
# Definir variables
df_filtrado = df_yt[df_yt['categoría'] != 'sin categoría']
counts = df_filtrado['categoría'].value_counts()
order = counts.index
values = counts.values

# %%
# Realizar gráfico de barras
colors = ['#001A70' if v == values.max() else '#CBC4BC' if v == values.min() else '#E6E8F0' for v in values]

plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
ax = sns.barplot(x=values, y=order, palette=colors, hue=order, legend=False)

for p in ax.patches: # Etiquetas de datos
    ax.annotate(f'{int(p.get_width())}',
                (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=11, fontweight='bold', xytext=(5, 0), textcoords='offset points')

plt.title('Cantidad Promedio de Vídeos Publicados por Categoría', loc='left', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Número de Videos Publicados')
plt.ylabel('Categoría de Contenido')
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### **PROMEDIO DE VISTAS POR CATEGORÍA**

# %%
# Definir variables
vistas_mean = df_yt.groupby('categoría')['views'].mean().sort_values(ascending=False)
colors_vistas = ['#4285F4' if v == vistas_mean.max() else '#D3D3D3' if v == vistas_mean.min() else '#C6D9F7' for v in vistas_mean]

# %%
# Realizar gráfico de barras
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
ax1 = sns.barplot(x=vistas_mean.values, y=vistas_mean.index, palette=colors_vistas, hue=vistas_mean.index, legend=False)

for p in ax1.patches: # Etiquetas y estética
    ax1.annotate(f'{int(p.get_width()):,}', (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=10, fontweight='bold', xytext=(5, 0), textcoords='offset points')

plt.title('Alcance Promedio de Vídeos Publicados por Categoría', loc='left', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Vistas Promedio')
plt.ylabel('Categoría')
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### **PROMEDIO DE COMENTARIOS POR CATEGORÍA**

# %%
# Definir variables
coments_mean = df_yt.groupby('categoría')['comentarios'].mean().sort_values(ascending=False)
colors_coments = ['#4285F4' if v == coments_mean.max() else '#D3D3D3' if v == coments_mean.min() else '#C6D9F7' for v in coments_mean]

# %%
# Realizar gráfico de barras

plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
ax2 = sns.barplot(x=coments_mean.values, y=coments_mean.index, palette=colors_coments, hue=coments_mean.index, legend=False)

for p in ax2.patches: # Etiquetas y estética
    ax2.annotate(f'{int(p.get_width()):,}', (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=10, fontweight='bold', xytext=(5, 0), textcoords='offset points')

plt.title('Interacción Promedio por Categoría', loc='left', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Comentarios Promedio')
plt.ylabel('Categoría')
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ## **CHALLENGE: EXPLORACIÓN DE DATOS AIRBNB CDMX**

# %% [markdown]
# Una vez visto el ***Hands - On: Exploración de datos***, se presentan las siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.
#
# Para este notebook, se hará uso del siguiente dataset: [enlace](https://drive.google.com/file/d/1HKCV2jFnumpJ1YNFI5cn6wgT2tEiKKfK/view?usp=drive_link)

# %% [markdown]
# Dentro de la siguiente dinámica, **se realizará un análisis exploratorio profundo sobre el catálogo de alojamientos de Airbnb en la Ciudad de México** para detectar patrones de comportamiento, valores atípicos y relaciones entre variables. Se hará uso de **herramientas estadísticas, técnicas de detección de outliers y narrativa visual** a través del dataset **"airbnb_clean"**.
#
# Donde los análisis a realizar son:
#
# * **Detección y tratamiento de valores atípicos mediante el rango intercuartílico**.
# * **Identificación de relaciones lineales entre variables numéricas**.
# * **Comunicación de hallazgos a través de narrativa visual por categoría**.

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Importaciones y análisis de resumen estadístico:**
#
# * Carga las bibliotecas de Pandas, Numpy, Seaborn y Matplotlib.pyplot.
# * Carga el archivo *airbnb_clean.csv*.
# * Obtén el resumen estadístico de los datos.

# %%
# Importar librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importar datos
ruta_airbnb = '/content/airbnb_clean.csv'
df_airbnb = pd.read_csv(ruta_airbnb)

df_airbnb
# Out:
#                         id                                              name  \
# 0                    35797                                       Villa Dante
# 1                    44616                                      Condesa Haus
# 2                    56074              Great space in historical San Rafael
# 3                    67703                 2 bedroom apt. deco bldg, Condesa
# 4                    70644  Beautiful light Studio Coyoacan- full equipped !
# ...                    ...                                               ...
# 27046  1518356968266486778                                       Suite Frida
# 27047  1518388105556721163   Habitación a un costado de Ciudad Universitaria
# 27048  1518433354720281854                 Espacioso departamento en Anzures
# 27049  1518462568893975567                                 Casa Roma Baja 05
# 27050  1518561444972990747       Departamento con Terraza privada Roma Norte
#
#          host_id        host_name          neighbourhood   latitude  \
# 0         153786             Dici  Cuajimalpa de Morelos  19.382830
# 1         196253         Fernando             Cuauhtémoc  19.411620
# 2         265650            Maris             Cuauhtémoc  19.439770
# 3         334451         Nicholas             Cuauhtémoc  19.411520
# 4         212109           Trisha               Coyoacán  19.354480
# ...          ...              ...                    ...        ...
# 27046  674644167         Heyliana    Venustiano Carranza  19.442240
# 27047  222854336    Marco Antonio               Coyoacán  19.308017
# 27048  470800231  Hector Fernando         Miguel Hidalgo  19.434460
# 27049  710857718           Camila             Cuauhtémoc  19.406435
# 27050  362149590             Ilse             Cuauhtémoc  19.413682
#
#        longitude        room_type    price  minimum_nights  number_of_reviews  \
# 0     -99.271780  Entire home/apt   3673.0               1                  0
# 1     -99.177940  Entire home/apt  18000.0               1                 65
# 2     -99.156050  Entire home/apt    591.0              15                 84
# 3     -99.168570  Entire home/apt   1039.0               2                 50
# 4     -99.162170  Entire home/apt   1039.0               3                134
# ...          ...              ...      ...             ...                ...
# 27046 -99.113440     Private room   1096.0               1                  0
# 27047 -99.168158     Private room    260.0               1                  0
# 27048 -99.174010  Entire home/apt    996.0               1                  0
# 27049 -99.160934  Entire home/apt    458.0               1                  0
# 27050 -99.154815  Entire home/apt   3082.0               1                  0
#
#           last_review  reviews_per_month  calculated_host_listings_count  \
# 0      Never reviewed               0.00                               1
# 1          2025-01-01               0.38                               9
# 2          2025-02-27               0.48                               1
# 3          2024-10-30               0.30                               2
# 4          2025-08-18               0.81                               3
# ...               ...                ...                             ...
# 27046  Never reviewed               0.00                               5
# 27047  Never reviewed               0.00                               1
# 27048  Never reviewed               0.00                              20
# 27049  Never reviewed               0.00                               7
# 27050  Never reviewed               0.00                               4
#
#        availability_365  number_of_reviews_ltm
# 0                   363                      0
# 1                   360                      1
# 2                   333                      1
# 3                   252                      1
# 4                   234                      8
# ...                 ...                    ...
# 27046               365                      0
# 27047               365                      0
# 27048               365                      0
# 27049               363                      0
# 27050               365                      0
#
# [27051 rows x 16 columns]

# %%
# Ver resumen estadístico
df_airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.705100e+04  2.705100e+04  27051.000000  27051.000000   27051.000000
# mean   7.003556e+17  2.429439e+08     19.405490    -99.165385    1695.489483
# std    5.702714e+17  2.062579e+08      0.042390      0.033535   12352.097771
# min    3.579700e+04  7.365000e+03     19.177848    -99.339630      61.000000
# 25%    4.410472e+07  5.621443e+07     19.392489    -99.178499     700.000000
# 50%    8.307368e+17  1.766835e+08     19.415390    -99.167100    1039.000000
# 75%    1.217382e+18  4.288830e+08     19.432015    -99.153731    1484.000000
# max    1.518561e+18  7.208445e+08     19.561010    -98.963360  900000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    27051.000000       27051.000000       27051.000000
# mean         4.580866          53.777679           1.621652
# std         24.784605          85.143043           2.219818
# min          1.000000           0.000000           0.000000
# 25%          1.000000           4.000000           0.210000
# 50%          2.000000          21.000000           1.000000
# 75%          2.000000          69.000000           2.370000
# max       1125.000000        1434.000000         119.460000
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# count                    27051.000000      27051.000000           27051.000000
# mean                        14.559868        232.686333              15.691028
# std                         31.892178        122.270858              23.615517
# min                          1.000000          0.000000               0.000000
# 25%                          1.000000        140.000000               0.000000
# 50%                          3.000000        269.000000               7.000000
# 75%                         11.000000        341.000000              23.000000
# max                        221.000000        365.000000             665.000000

# %% [markdown]
# **2. Análisis de distribución y filtrado de outliers:**
#
# * Genera un histograma y diagrama de caja sobre la columna `price`.
# * Calcula la cantidad de registros con los que cuenta el dataframe.
# * Calcula el rango intercuartílico y filtra el dataframe con los registros dentro de los límites.
# * Calcula la cantidad y proporción de registros finales y grafica su diagrama de caja.

# %%
# Observar distribución y comportamiento cuartil de los datos
plt.figure(figsize=(15,9))

col_price = df_airbnb['price']

plt.subplot(1, 2, 1)
sns.histplot(col_price, bins=10, kde=True, color='teal')
plt.title(f'Distribución de price')
plt.xlabel('price')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha = 0.75)

plt.subplot(1, 2, 2)
sns.boxplot(x = col_price, color = 'pink')
plt.title(f'Diagrama de caja y bigotes: price')
plt.xlabel('price')

plt.tight_layout()
plt.show()

# %%
# Ver cantidad de registros iniciales
print(f'Cantidad de registros iniciales: {len(df_airbnb)}')
# Out:
# Cantidad de registros iniciales: 27051

# %%
# Calculo del IQR
df_copy_airbnb=df_airbnb.copy()

Q1_airbnb = df_copy_airbnb['price'].quantile(0.25)
Q3_airbnb = df_copy_airbnb['price'].quantile(0.75)
IQR_airbnb = Q3_airbnb - Q1_airbnb

lim_inf_iqr_airbnb=Q1_airbnb - 1.5 * IQR_airbnb
lim_sup_iqr_airbnb=Q3_airbnb + 1.5 * IQR_airbnb

cant_inicial_airbnb = len(df_copy_airbnb)
df_copy_airbnb = df_copy_airbnb[(df_copy_airbnb['price'] >= lim_inf_iqr_airbnb)
                                & (df_copy_airbnb['price'] <= lim_sup_iqr_airbnb)]
cant_final_airbnb = len(df_copy_airbnb)

print(f'Cantidad de datos con outliers eliminados en price: {cant_inicial_airbnb - cant_final_airbnb}')
# Out:
# Cantidad de datos con outliers eliminados en price: 2310

# %%
# Ver cantidad y proporción con la cantidad inicial
prop_cant_datos_airbnb = round((len(df_copy_airbnb) / len(df_airbnb)) * 100, 2)

print(f'Cantidad de datos finales: {len(df_copy_airbnb)}')
print(f'Proporción de datos útiles: {prop_cant_datos_airbnb}%')
# Out:
# Cantidad de datos finales: 24741
# Proporción de datos útiles: 91.46%

# %%
# Observar comportamiento cuartil final de los datos
plt.figure(figsize=(15,9))

col_price_sin_outliers = df_copy_airbnb['price']

plt.subplot(1, 2, 1)
sns.histplot(col_price_sin_outliers, bins=10, kde=True, color='teal')
plt.title(f'Distribución de price')
plt.xlabel('price')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha = 0.75)

plt.subplot(1, 2, 2)
sns.boxplot(x = col_price_sin_outliers, color = 'pink')
plt.title(f'Diagrama de caja y bigotes: price')
plt.xlabel('price')

plt.tight_layout()
plt.show()

# %% [markdown]
# **3. Análisis de correlaciones:**
#
# * Genera una matriz de correlación sobre las columnas numéricas del dataframe.
# * Selecciona las variables numéricas más representativas.
# * Realiza correlaciones divididas por categoría segmentadas por la columna `room_type`.

# %%
col_num_airbnb = ['price', 'latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm', 'id', 'host_id']

corr_matrix_airbnb = df_copy_airbnb[col_num_airbnb].corr()

plt.figure(figsize = (10, 8))
sns.heatmap(corr_matrix_airbnb, annot = True, cmap = 'coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title('Matriz de Correlación para Airbnb')
plt.show()

# %%
# Realizar correlaciones divididas
metricas_airbnb = ['price', 'minimum_nights', 'reviews_per_month', 'number_of_reviews', 'number_of_reviews_ltm']

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(36, 12))
axes = axes.flatten() # Aplanamos para iterar fácilmente

# Pares de comparación por
comparaciones_airbnb = [
    ('price', 'minimum_nights'), ('price', 'reviews_per_month'), ('price', 'number_of_reviews'),
    ('price', 'number_of_reviews_ltm'), ('minimum_nights', 'reviews_per_month'), ('minimum_nights', 'number_of_reviews'),
    ('minimum_nights', 'number_of_reviews_ltm'), ('number_of_reviews', 'reviews_per_month'),
    ('number_of_reviews', 'number_of_reviews_ltm'), ('reviews_per_month', 'number_of_reviews_ltm')
]

for i, (col_x, col_y) in enumerate(comparaciones_airbnb):
    sns.regplot(ax=axes[i], data=df_copy_airbnb, x=col_x, y=col_y,
                scatter_kws={'alpha':0.3, 'color':'darkorchid'},
                line_kws={'color':'red'})
    axes[i].set_title(f'{col_x.title()} vs {col_y.title()}')
    axes[i].grid(True, alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# **4. Regresión lineal simple:**
#
# * Define como variable independiente `reviews_per_month` y como dependiente `number_of_reviews_ltm`.
# * Calcula los coeficientes para determinar la ecuación del modelo de regresión lineal simple.
# * Ajusta el modelo de regresión lineal con descenso de gradiente y determina la nueva ecuación.
# * Visualizar el modelo de regresión lineal ajustada y la curva de perdidas.
# * Calcula la reducción del error desde la primera hasta la última época.

# %%
# Cálculo de la regresión lineal simple
y = df_copy_airbnb['number_of_reviews_ltm']
x = df_copy_airbnb['reviews_per_month']

beta, alpha = np.polyfit(x, y, 1)
print(f'y = {round(beta, 2)}x + {round(alpha, 2)}')
# Out:
# y = 9.06x + 1.01

# %%
# Calculo del descenso de gradiente
# Definir parámetros

tamaño_paso = 0.05
theta_0 = 0
theta_1 = 0

# Realizar algoritmo del descenso de gradiente

iteraciones = 100
perdida = []

for i in range(iteraciones):

  y_prediccion = theta_1*x + theta_0
  error = ((y_prediccion - y) ** 2).mean()
  perdida.append(error)

  d_theta_0 = 2*(y_prediccion - y).mean()
  d_theta_1 = 2*((y_prediccion - y) * x).mean()

  theta_0 = theta_0 - tamaño_paso * d_theta_0
  theta_1 = theta_1 - tamaño_paso * d_theta_1

print(f'y = {round(theta_1, 2)}x + {round(theta_0, 2)}')
# Out:
# y = 9.06x + 1.01

# %%
# Visualizar regresión lineal y perdidas
plt.subplot(1, 2, 1)
plt.scatter(x, y, color = 'lightgray', label = 'Datos')
plt.plot(x, beta*x + alpha, color = 'red', label = 'Ajuste de curva')
plt.title('Regresión lineal')
plt.xlabel('reviews_per_month')
plt.ylabel('Number of reviews ltm')
plt.legend(loc = 'upper left')

plt .subplot(1, 2, 2)
plt.plot(perdida, label = 'Errores')
plt.title('Función de number of reviews ltm')
plt.xlabel('Iteraciones')
plt.ylabel('Pérdida')
plt.grid()
plt.show()

# %%
# Registro final de perdida
error_inicial = perdida[0]
error_final = perdida[-1]

# Reducción absoluta
reduccion_absoluta = error_inicial - error_final

# Reducción porcentual
reduccion_porcentual = (reduccion_absoluta / error_inicial) * 100

print(f'Error en la primera época: {round(error_inicial, 4)}')
print(f'Error en la última época: {round(error_final, 4)}')
print(
    f'Reducción del error (Absoluta): {round(reduccion_absoluta, 4)}'
)
print(f'Porcentaje de reducción del error: {round(reduccion_porcentual, 2)}%')
# Out:
# Error en la primera época: 839.4546
# Error en la última época: 159.4647
# Reducción del error (Absoluta): 679.9899
# Porcentaje de reducción del error: 81.0%

# %% [markdown]
# **5. Comparación por categoría:**
#
# * Utiliza un gráfico de barras para mostrar el precio promedio por tipo de habitación.
# * Utiliza un diagrama de caja para visualizar la distribución del precio por tipo de habitación.
# * Agrupa el dataframe por la columna `room_type` y calcula el conteo de alojamientos.
# * Utiliza un gráfico de dona que muestre el porcentaje de cada categoría.

# %%
# Realizar gráficos de barras divididas
plt.figure(figsize=(15, 6))
sns.barplot(data=df_copy_airbnb, x='price', y='room_type',
            estimator='mean', palette='viridis', errorbar=None, hue='room_type', legend=False)
plt.title('Promedio de precio por tipo de habitación')
plt.xlabel('Precio Promedio')

plt.tight_layout()
plt.show()

# %%
# Realizar gráfico de barras y caja divididos
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.barplot(data=df_copy_airbnb, x='price', y='room_type',
            estimator='mean', palette='magma', errorbar=None, hue='room_type', legend=False)
plt.title('Promedio de Precio por Tipo de habitación')
plt.xlabel('Precio Promedio')

plt.subplot(1, 2, 2)
sns.boxplot(data=df_copy_airbnb, x='room_type', y='price', palette='magma', hue='room_type', legend=False)
plt.title('Distribución de Precio por tipo de habitación')
plt.xlabel('Tipo de habitación')
plt.ylabel('Precio')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.75)

plt.tight_layout()
plt.show()

# %%
# Definir variables para la agrupación
clasificar_room = lambda x: 'Compartido' if x == 'Shared room' else 'Privado/Completo'

df_copy_airbnb['agrupacion_room'] = df_copy_airbnb['room_type'].apply(clasificar_room)
pie_data_airbnb = df_copy_airbnb['agrupacion_room'].value_counts()

# %%
# Realizar gráfico de dona
colors_pie = ['#6424AB', '#E6E8F0'] # Azul = "Compartido", Gris = "Privado/Completo"
explode_val = 0.2 # Valor de separación

# Gráfico de pastel

plt.figure(figsize=(6, 6))
wedges, texts, autotexts = plt.pie(pie_data_airbnb,
                                   labels=pie_data_airbnb.index,
                                   autopct='%1.1f%%',
                                   startangle=90,
                                   colors=colors_pie,
                                   textprops={'fontsize': 12, 'fontweight': 'bold'},
                                   pctdistance=0.85, # Mueve el porcentaje hacia afuera
                                   explode=(explode_val, 0)) # Resalta ligeramente la porción principal

# Círculo blanco central (estilo moderno)

theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center_angle = np.deg2rad((theta1 + theta2) / 2) # Obtención el ángulo medio

cx = explode_val * np.cos(center_angle) # Se Calcula nueva posición con trigonometría
cy = explode_val * np.sin(center_angle)

centre_circle = plt.Circle((cx, cy), 0.70, fc='white') # Se dibuja el circulo
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Proporción Categórica de tipos de habitaciones', fontsize=16, fontweight='bold', pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# **6. Narrativa visual:**
#
# * Utiliza un gráfico de barras horizontales para mostrar el conteo de alojamientos por alcaldía.
# * Utiliza un gráfico de barras horizontales para mostrar el precio promedio por alcaldía.
# * Utiliza un gráfico de barras horizontales para mostrar el promedio de reseñas por alcaldía.

# %%
# Definir variables para el conteo de alojamientos por alcaldía
counts = df_copy_airbnb['neighbourhood'].value_counts()
order = counts.index
values = counts.values

# %%
# Realizar gráfico de barras
colors = ['#001A70' if v == values.max() else '#CBC4BC' if v == values.min() else '#E6E8F0' for v in values]

plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
ax = sns.barplot(x=values, y=order, palette=colors, hue=order, legend=False)

for p in ax.patches: # Etiquetas de datos
    ax.annotate(f'{int(p.get_width())}',
                (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=11, fontweight='bold', xytext=(5, 0), textcoords='offset points')

plt.title('Cantidad de alojamientos por Alcaldía', loc='left', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Cantidad de Alojamientos')
plt.ylabel('Alcaldías')
sns.despine(left=True, bottom=True)
plt.show()

# %%
# Definir variables para calcular el precio promedio por alcaldía
precio_mean = df_copy_airbnb.groupby('neighbourhood')['price'].mean().sort_values(ascending=False)
colors_price_alcaldia = ['#4285F4' if v == precio_mean.max() else '#D3D3D3' if v == precio_mean.min() else '#C6D9F7' for v in precio_mean]

# %%
# Realizar gráfico de barras
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
ax1 = sns.barplot(x=precio_mean.values, y=precio_mean.index, palette=colors_price_alcaldia, hue=precio_mean.index, legend=False)

for p in ax1.patches: # Etiquetas y estética
    ax1.annotate(f'{int(p.get_width()):,}', (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=10, fontweight='bold', xytext=(5, 0), textcoords='offset points')

plt.title('Precios promedio de habitaciones de Airbnb por Alcaldía', loc='left', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Precios Promedio')
plt.ylabel('Alcaldía')
sns.despine(left=True, bottom=True)
plt.show()

# %%
# Definir variables para calcular promedio de reseñas por Alcaldía
reviews_mean = df_copy_airbnb.groupby('neighbourhood')['number_of_reviews'].mean().sort_values(ascending=False)
colors_reviews = ['#4285F4' if v == reviews_mean.max() else '#D3D3D3' if v == reviews_mean.min() else '#C6D9F7' for v in reviews_mean]

# %%
# Realizar gráfico de barras
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
ax1 = sns.barplot(x=reviews_mean.values, y=reviews_mean.index, palette=colors_reviews, hue=reviews_mean.index, legend=False)

for p in ax1.patches: # Etiquetas y estética
    ax1.annotate(f'{int(p.get_width()):,}', (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=10, fontweight='bold', xytext=(5, 0), textcoords='offset points')

plt.title('Número de reseñas promedio de habitaciones de Airbnb por Alcaldía', loc='left', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Número de reseñas Promedio')
plt.ylabel('Alcaldía')
sns.despine(left=True, bottom=True)
plt.show()
